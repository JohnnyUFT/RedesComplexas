# %% [markdown]
# # Covid-19 - Brasil
# ## bla bla bla

# %%
import numpy as np
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("./data/begin_covid.csv")

# %%
#df.head()
df.tail()
# Out:
#      regiao  coduf   data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 99   Brasil     76  43986         23         210147125          614941
# 100  Brasil     76  43987         23         210147125          645771
# 101  Brasil     76  43988         23         210147125          672846
# 102  Brasil     76  43989         24         210147125          691758
# 103  Brasil     76  43990         24         210147125          707412
#
#      casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# 99        30925            34021         1473          254963.0
# 100       30830            35026         1005          266940.0
# 101       27075            35930          904          277149.0
# 102       18912            36455          525          283952.0
# 103       15654            37134          679          290040.0
#
#      emAcompanhamentoNovos
# 99                325957.0
# 100               343805.0
# 101               359767.0
# 102               371351.0
# ...

# %%
# from bokeh.io import output_notebook, show
# output_notebook()

# %%
sns.set(style="white")

# %%
df
# Out:
#      regiao  coduf   data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 0    Brasil     76  43887          9         210147125               1
# 1    Brasil     76  43888          9         210147125               1
# 2    Brasil     76  43889          9         210147125               1
# 3    Brasil     76  43890          9         210147125               2
# 4    Brasil     76  43891         10         210147125               2
# ..      ...    ...    ...        ...               ...             ...
# 99   Brasil     76  43986         23         210147125          614941
# 100  Brasil     76  43987         23         210147125          645771
# 101  Brasil     76  43988         23         210147125          672846
# 102  Brasil     76  43989         24         210147125          691758
# 103  Brasil     76  43990         24         210147125          707412
#
#      casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# ...

# %%
# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="semanaEpi", y="casosNovos",
            sizes=(60, 600), alpha=.5, size='casosNovos', palette="muted",
            height=6, data=df)

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show

# %%
radii = np.random.random(size=N) * 1.5

# %%
# aqui teria que usar o interpolador
# mesmo metodo utilizado pela Sarah na apresentacao do PyData
print(radii)
# Out:
# [0.66792908 1.13669878 0.94896176 0.66377813 0.18726785 0.23776789
#  0.0610564  0.00773273 1.19236664 0.33217089 0.60550674 0.42728439
#  1.12671032 1.23257713 0.9436126  0.06012975 0.2655348  0.85040084
#  0.42246917 0.71592128 1.1863064  0.95948225 0.55590626 0.98581523
#  0.25570945 0.65780953 0.51513359 1.42140852 0.01763038 0.35162703
#  1.36393024 0.28028664 1.00486501 0.9475962  0.88700966 0.02849457
#  0.54001033 0.95810607 1.00332273 0.21379557 0.17030584 1.22708279
#  0.38287668 0.80610218 0.53919832 1.07825639 1.2347619  1.43798882
#  1.41030474 0.45894403 1.19179516 1.41370445 0.31085969 0.0132988
#  0.49940077 0.77742861 0.90679127 1.28479341 0.82668852 0.17784979
#  0.2081474  0.44685047 1.32128149 0.82249246 0.38935047 0.48783309
#  1.39851271 1.00234201 0.51375418 0.93287608 0.13811154 0.28359963
#  0.4451415  1.10821966 0.84260162 0.72765489 1.3416396  0.8080347
#  0.93623291 0.44509264 1.49325761 1.38315432 1.12072495 0.67341154
# ...

# %%
N = 104
x = df['semanaEpi']
y = df['casosNovos']
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"

p = figure(tools=TOOLS)

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)

output_file("brasil_casos_primeiras_semanas.html", title="Crescimento Casos Primeiras Semanas")

show(p)  # open a browser
# Out:
#   <div class="bk-root" id="198e5110-23d3-46d5-86c9-d121e2e46c6d" data-root-id="1276"></div>
